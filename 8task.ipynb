# %%
import numpy as np 
import pandas as pd
import math
import matplotlib.pyplot as plt 
import scipy.optimize
from scipy.stats import poisson, chi2
from scipy.stats import moment

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

n = 200
index = ["Партия 1", "Партия 2"] # Bi
columns = ["Заниженный размер", "Точный размер", "Завышенный размер"] # Ai
data_df = pd.DataFrame(columns=columns, index = pd.Index(index))
data_df.loc["Партия 1", :] = np.array([25, 50, 25])
data_df.loc["Партия 2", :] = np.array([52, 41, 7])
data_df
# Out:
#          Заниженный размер Точный размер Завышенный размер
# Партия 1                25            50                25
# Партия 2                52            41                 7

# %%
# ищем p_i и q_j для
p_df = pd.DataFrame(columns=[1, 2], index=pd.Index(["p_i"]))
p_df.loc["p_i", :] = np.array([np.sum(data_df.loc[data_df.index[i], :])/n for i in (0, 1)])
q_df = pd.DataFrame(columns=[1, 2, 3], index=pd.Index(["q_j"]))
q_df.loc["q_j", :] = np.array([np.sum(data_df.loc[pd.Index(index), columns[i]])/n for i in (0, 1, 2)])
def pretty_print(df, title=""):
    style = df.style \
        .set_properties(**{
            'text-align': 'center',
            'border': '1px solid black',
            'padding': '5px'
        }) \
        .set_table_styles([{
            'selector': 'th',
            'props': [('background-color', '#f7f7f7'),
                     ('font-weight', 'bold')]
        }]) \
        .format("{:.4f}")

    if title:
        display(style.set_caption(title))
    else:
        display(style)

print("Вероятности p_i:")
pretty_print(p_df, "p_i")

print("\nВероятности q_j:")
pretty_print(q_df, "q_j")
# Out:
# Вероятности p_i:
# <style type="text/css">
# #T_e677d th {
#   background-color: #f7f7f7;
#   font-weight: bold;
# }
# #T_e677d_row0_col0, #T_e677d_row0_col1 {
#   text-align: center;
#   border: 1px solid black;
#   padding: 5px;
# }
# </style>
# <table id="T_e677d">
#   <caption>p_i</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e677d_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_e677d_level0_col1" class="col_heading level0 col1" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e677d_level0_row0" class="row_heading level0 row0" >p_i</th>
#       <td id="T_e677d_row0_col0" class="data row0 col0" >0.5000</td>
#       <td id="T_e677d_row0_col1" class="data row0 col1" >0.5000</td>
#     </tr>
#   </tbody>
# </table>
# Вероятности q_j:
# <style type="text/css">
# #T_23f08 th {
#   background-color: #f7f7f7;
#   font-weight: bold;
# }
# #T_23f08_row0_col0, #T_23f08_row0_col1, #T_23f08_row0_col2 {
#   text-align: center;
#   border: 1px solid black;
#   padding: 5px;
# }
# </style>
# <table id="T_23f08">
#   <caption>q_j</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23f08_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_23f08_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_23f08_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23f08_level0_row0" class="row_heading level0 row0" >q_j</th>
#       <td id="T_23f08_row0_col0" class="data row0 col0" >0.3850</td>
#       <td id="T_23f08_row0_col1" class="data row0 col1" >0.4550</td>
#       <td id="T_23f08_row0_col2" class="data row0 col2" >0.1600</td>
#     </tr>
#   </tbody>
# </table>

# %%
delta = 0
for i in (1, 2):
    for j in (1, 2, 3):
        m_ij = data_df.loc[index[i-1], columns[j-1]]
        p_i = p_df.loc["p_i", i]
        q_j = q_df.loc["q_j", j]
        delta += (m_ij - n*p_i*q_j)**2/(n*p_i*q_j)
print(f"delta = {delta}")
# Out:
# delta = 20.48264235764236

# %%
sf = chi2.sf(delta, (2-1)*(3-1))
print(sf)
# Out:
# 3.566569773595299e-05

# %% [markdown]
# ## p-value < 0.05, следовательно результат является стат. значимым, отвергаем H0.
